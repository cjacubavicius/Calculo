# %% [markdown]
# # **FUNÇÕES**

# %%
import sympy as sy

# %%
x = sy.Symbol('x')

# %%
from sympy import plotting

# %% [markdown]
# # **FUNÇÕES EXPONENCIAIS**

# %%
sy.plot(2**x, (x,-2,2));

# %%
sy.plot((1/2)**x, (x,-3,5));

# %%
sy.plot(3*(1/2)**x, (x,-2,2));
